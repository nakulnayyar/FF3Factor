# %%
import pandas as pd
import numpy as np
from StringIO import StringIO
from zipfile import ZipFile
from urllib import urlopen
import pandas.io.data as web
from datetime import datetime, timedelta
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'test', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
url = urlopen("http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_CSV.zip")

#Download Zipfile and create pandas DataFrame
zipfile = ZipFile(StringIO(url.read()))
FFdata = pd.read_csv(zipfile.open('F-F_Research_Data_Factors.CSV'), 
                     header = 0, names = ['Date','MKT-RF','SMB','HML','RF'], 
                     skiprows=3)

#Drop last row of data - String
FFdata = FFdata[:1074]

#Convert YYYYMM into Date
FFdata['Date'] = pd.to_datetime(FFdata['Date'], format = "%Y%m")
FFdata.index = FFdata['Date']
FFdata.drop(FFdata.columns[0], axis=1,inplace=True)

#Drop Days in YYYY-MM-DD
FFdata.index = FFdata.index.map(lambda x: x.strftime('%Y-%m'))

#Convert into float
FFdata = FFdata.astype('float')
FFdata.tail()
# Out:
#          MKT-RF   SMB   HML    RF
# 2015-08   -6.04  0.43  2.88  0.00
# 2015-09   -3.07 -2.71  0.73  0.00
# 2015-10    7.75 -1.86 -0.32  0.00
# 2015-11    0.56  3.55 -1.23  0.00
# 2015-12   -2.17 -2.98 -2.05  0.01

# %%
#Import Fund Data
#Tweedy, Browne Global Value Fund - Ticker TBGVX from YahooFinance

#Get Data from Yahoo
start = datetime.datetime(1950,1,1)
end = datetime.datetime(2016,1,1)
f = web.get_data_yahoo("TBGVX", start, end, interval='m')

#Delete Columns
f.drop(f.columns[[0,1,2,3,4]], axis=1, inplace=True)
#Fix Date Column
f.index = f.index.map(lambda x: x.strftime('%Y-%m'))
#Ln Return
f['LnReturn'] = np.log(f['Adj Close']) - np.log(f['Adj Close'].shift(1))
f.head()
# Out:
#          Adj Close  LnReturn
# 1993-06   3.196204       NaN
# 1993-07   3.305093  0.033501
# 1993-08   3.426792  0.036160
# 1993-09   3.301891 -0.037129
# 1993-10   3.426792  0.037129

# %%
#Merge DF
data2 = pd.concat([f,FFdata], axis = 1)

#Excess Return
data2['XRtrn'] = (data2['LnReturn']*100 - data2['RF'])
#Align Data
df = data2[np.isfinite(data2['XRtrn'])]

df.tail()
# Out:
#          Adj Close  LnReturn  MKT-RF   SMB   HML    RF     XRtrn
# 2015-08  24.537291 -0.042576   -6.04  0.43  2.88  0.00 -4.257579
# 2015-09  23.841671 -0.028759   -3.07 -2.71  0.73  0.00 -2.875911
# 2015-10  25.118563  0.052172    7.75 -1.86 -0.32  0.00  5.217220
# 2015-11  25.013742 -0.004182    0.56  3.55 -1.23  0.00 -0.418178
# 2015-12  24.459999 -0.022386   -2.17 -2.98 -2.05  0.01 -2.248626

# %%
#df = data2[np.isfinite(data2['XRtrn'])]

y = df['XRtrn']
X = df.ix[:,[2,3,4]]
X = sm.add_constant(X)


model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  XRtrn   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     185.1
# Date:                Wed, 03 Feb 2016   Prob (F-statistic):           8.19e-65
# Time:                        08:51:00   Log-Likelihood:                -568.87
# No. Observations:                 270   AIC:                             1146.
# Df Residuals:                     266   BIC:                             1160.
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0799      0.124      0.646      0.519        -0.164     0.324
# MKT-RF         0.6659      0.029     22.845      0.000         0.609     0.723
# SMB            0.0668      0.039      1.704      0.090        -0.010     0.144
# HML            0.2626      0.042      6.293      0.000         0.180     0.345
# ==============================================================================
# Omnibus:                        8.751   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):               15.019
# Skew:                          -0.115   Prob(JB):                     0.000548
# Kurtosis:                       4.132   Cond. No.                         4.80
# ==============================================================================

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(results, fig = fig)
plt.show()

#sns.lmplot(x="MKT-RF", y="XRtrn", data=data2)

# %%
#df.tail()
print y
# Out:
# 2007-11   -0.506439
# 2007-12   -0.379660
# 2008-01   -0.223463
# 2008-02   -0.146705
# 2008-03   -0.302438
# 2008-04    0.187456
# 2008-05   -0.374502
# 2008-06   -0.516226
# 2008-07   -0.152081
# 2008-08   -0.203467
# 2008-09    0.003510
# 2008-10   -0.944757
# 2008-11    0.175640
# 2008-12   -0.160990
# 2009-01   -0.202613
# 2009-02    0.057209
# 2009-03    0.253837
# 2009-04    0.811437
# 2009-05   -0.039221
# 2009-06    0.044159
# 2009-07    0.266083
# 2009-08   -0.061293
# 2009-09   -0.062679
# 2009-10   -0.029559
# 2009-11    0.239017
# 2009-12    0.107658
# 2010-01    0.080658
# 2010-02    0.079759
# 2010-03    0.058311
# 2010-04    0.025174
# 2010-05   -0.114337
# 2010-06   -0.161596
# 2010-07    0.226545
# 2010-08   -0.133181
# 2010-09    0.070792
# 2010-10    0.133591
# 2010-11    0.110532
# 2010-12    0.041952
# 2011-01   -0.061325
# 2011-02   -0.068081
# 2011-03   -0.019346
# 2011-04    0.036871
# 2011-05   -0.036200
# 2011-06   -0.078759
# 2011-07   -0.121688
# 2011-08   -0.103510
# 2011-09   -0.139717
# 2011-10    0.188850
# 2011-11   -0.097024
# 2011-12    0.014982
# 2012-01    0.147389
# 2012-02   -0.003226
# 2012-03    0.008045
# 2012-04   -0.096776
# 2012-05   -0.075958
# 2012-06   -0.096352
# 2012-07   -0.037179
# 2012-08    0.006190
# 2012-09    0.044180
# 2012-10   -0.002926
# Name: XRtrn, dtype: float64
